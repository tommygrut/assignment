# %%
import pandas as panda 
from matplotlib import pyplot as plt

# %%
dataframe = panda.read_csv("Ruter_data.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-2-827db9a82529> in <module>
# ----> 1 dataframe = panda.read_csv("Ruter_data.csv")
#       2
#
# ~\miniconda3\envs\dave3625\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# ...

# %%
panda.read_csv(‘Ruter_data.csv’, delimiter=‘;’)
# Out:
#   File "<ipython-input-3-db91894f8e48>", line 1
#     panda.read_csv(‘Ruter_data.csv’, delimiter=‘;’)
#                              ^
# SyntaxError: invalid character in identifier

# %%
panda.read_csv(‘Ruter_data.csv’, delimiter=‘;’)
# Out:
#   File "<ipython-input-4-db91894f8e48>", line 1
#     panda.read_csv(‘Ruter_data.csv’, delimiter=‘;’)
#                              ^
# SyntaxError: invalid character in identifier

# %%
dataframe = panda.read_csv(‘Ruter_data.csv’, delimiter=‘;’)
# Out:
#   File "<ipython-input-5-2ee29b776a3d>", line 1
#     dataframe = panda.read_csv(‘Ruter_data.csv’, delimiter=‘;’)
#                                          ^
# SyntaxError: invalid character in identifier

# %%
dataframe = panda.read_csv("Ruter_data.csv", delimiter=‘;’)
# Out:
#   File "<ipython-input-6-28a8754128ab>", line 1
#     dataframe = panda.read_csv("Ruter_data.csv", delimiter=‘;’)
#                                                            ^
# SyntaxError: invalid character in identifier

# %%
dataframe = panda.read_csv("Ruter_data.csv, delimiter=";"")
# Out:
#   File "<ipython-input-7-c14f8452ddd9>", line 1
#     dataframe = panda.read_csv("Ruter_data.csv, delimiter=";"")
#                                                            ^
# SyntaxError: invalid syntax

# %%
dataframe = panda.read_csv("Ruter_data.csv", delimiter=";")

# %%
dataframe.head()
# Out:
#                              TurId        Dato  Fylke Område Kommune  \
# 0  15006-2020-08-10T10:24:00+02:00  10/08/2020  Viken   Vest   Bærum
# 1  15002-2020-08-15T12:54:00+02:00  15/08/2020  Viken   Vest   Bærum
# 2  15004-2020-08-03T09:54:00+02:00  03/08/2020  Viken   Vest   Bærum
# 3  15003-2020-07-27T13:00:00+02:00  27/07/2020  Viken   Vest   Bærum
# 4  15002-2020-08-27T07:15:00+02:00  27/08/2020  Viken   Vest   Bærum
#
#                   Holdeplass_Fra                        Holdeplass_Til  \
# 0                    Nordliveien                             Tjernsmyr
# 1               Nadderud stadion  Bekkestua bussterminal (Plattform C)
# 2               Ringstabekkveien                               Skallum
# 3                      Gruvemyra                              Gullhaug
# 4  Lysaker stasjon (Plattform A)                             Tjernsmyr
#
#   Linjetype Linjefylke Linjenavn  Linjeretning  \
# 0     Lokal      Viken       150             0
# ...

# %%
plt.hist(dataframe.age, bins=10, rwidth=0.8) plt.xlabel('Age') plt.ylabel('Count') plt.show()
# Out:
#   File "<ipython-input-10-9e24106ac3ae>", line 1
#     plt.hist(dataframe.age, bins=10, rwidth=0.8) plt.xlabel('Age') plt.ylabel('Count') plt.show()
#                                                  ^
# SyntaxError: invalid syntax

# %%
plt.hist(dataframe.age, bins=10, rwidth=0.8)
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-442464ba6d40> in <module>
# ----> 1 plt.hist(dataframe.age, bins=10, rwidth=0.8)
#       2 plt.xlabel('Age')
#       3 plt.ylabel('Count')
#       4 plt.show()
#       5
#
# ~\miniconda3\envs\dave3625\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5128             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5129                 return self[name]
# -> 5130             return object.__getattribute__(self, name)
#    5131
#    5132     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'age'

# %%
plt.hist(dataframe.age, bins=10, rwidth=0.8)
plt.xlabel('Dato')
plt.ylabel('Kommune') 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-a2b8e1adc39c> in <module>
# ----> 1 plt.hist(dataframe.age, bins=10, rwidth=0.8)
#       2 plt.xlabel('Dato')
#       3 plt.ylabel('Kommune')
#       4 plt.show()
#       5
#
# ~\miniconda3\envs\dave3625\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5128             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5129                 return self[name]
# -> 5130             return object.__getattribute__(self, name)
#    5131
#    5132     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'age'

# %%
plt.hist(dataframe.dato, bins=10, rwidth=0.8)
plt.xlabel('Dato')
plt.ylabel('Count') 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-9d689112a7ef> in <module>
# ----> 1 plt.hist(dataframe.dato, bins=10, rwidth=0.8)
#       2 plt.xlabel('Dato')
#       3 plt.ylabel('Count')
#       4 plt.show()
#
# ~\miniconda3\envs\dave3625\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5128             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5129                 return self[name]
# -> 5130             return object.__getattribute__(self, name)
#    5131
#    5132     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'dato'

# %%
plt.hist(dataframe.date, bins=10, rwidth=0.8)
plt.xlabel('Dato')
plt.ylabel('Count') 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-d756fd01314e> in <module>
# ----> 1 plt.hist(dataframe.date, bins=10, rwidth=0.8)
#       2 plt.xlabel('Dato')
#       3 plt.ylabel('Count')
#       4 plt.show()
#
# ~\miniconda3\envs\dave3625\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5128             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5129                 return self[name]
# -> 5130             return object.__getattribute__(self, name)
#    5131
#    5132     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'date'

# %%
plt.hist(dataframe.område, bins=10, rwidth=0.8)
plt.xlabel('Område')
plt.ylabel('Count') 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-8b6c84f2641b> in <module>
# ----> 1 plt.hist(dataframe.område, bins=10, rwidth=0.8)
#       2 plt.xlabel('Område')
#       3 plt.ylabel('Count')
#       4 plt.show()
#
# ~\miniconda3\envs\dave3625\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5128             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5129                 return self[name]
# -> 5130             return object.__getattribute__(self, name)
#    5131
#    5132     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'område'

# %%
plt.hist(dataframe.Område, bins=10, rwidth=0.8)
plt.xlabel('Område')
plt.ylabel('Count') 
plt.show()

# %%
thresold_max = dataframe['age'].quantile(0.90)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\miniconda3\envs\dave3625\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-1351e9d459b1> in <module>
# ...

# %%
thresold_max = dataframe['Fylke'].quantile(0.90)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-934b504c7515> in <module>
# ----> 1 thresold_max = dataframe['Fylke'].quantile(0.90)
#
# ~\miniconda3\envs\dave3625\lib\site-packages\pandas\core\series.py in quantile(self, q, interpolation)
#    2259         df = self.to_frame()
#    2260
# -> 2261         result = df.quantile(q=q, interpolation=interpolation, numeric_only=False)
#    2262         if result.ndim == 2:
#    2263             result = result.iloc[:, 0]
#
# ~\miniconda3\envs\dave3625\lib\site-packages\pandas\core\frame.py in quantile(self, q, axis, numeric_only, interpolation)
#    9054             return self._constructor_sliced([], index=cols, name=q, dtype=np.float64)
#    9055
# -> 9056         result = data._mgr.quantile(
#    9057             qs=q, axis=1, interpolation=interpolation, transposed=is_transposed
#    9058         )
#
# ...

# %%
thresold_max = dataframe['Kjøretøy_Kapasitet'].quantile(0.90)

# %%
thresold_max
# Out:
# 151.0

# %%
thresold_min = dataframe['Kjøretøy_Kapasitet'].quantile(0.10) thresold_min
# Out:
#   File "<ipython-input-21-dae25d67ab8c>", line 1
#     thresold_min = dataframe['Kjøretøy_Kapasitet'].quantile(0.10) thresold_min
#                                                                   ^
# SyntaxError: invalid syntax

# %%
thresold_min = dataframe['Kjøretøy_Kapasitet'].quantile(0.10)
thresold_min
# Out:
# 72.0

# %%
dataframe[dataframe['Kjøretøy_Kapasitet']<thresold_min]
# Out:
#                                 TurId        Dato  Fylke    Område  \
# 16    43111-2020-06-16T07:12:00+02:00  16/06/2020  Viken   Nordøst
# 52     6003-2020-06-03T13:55:00+02:00  03/06/2020   Oslo  Indre By
# 55     6003-2020-07-08T07:55:00+02:00  08/07/2020   Oslo   Nordøst
# 56     6002-2020-06-09T06:32:00+02:00  09/06/2020   Oslo   Nordøst
# 65    27058-2020-08-19T08:35:00+02:00  19/08/2020  Viken      Vest
# ...                               ...         ...    ...       ...
# 5938   4605-2020-08-09T21:02:00+02:00  09/08/2020   Oslo      Vest
# 5942   4601-2020-07-09T13:31:00+02:00  09/07/2020   Oslo      Vest
# 5945   4601-2020-08-25T13:46:00+02:00  25/08/2020   Oslo      Vest
# 5949   4004-2020-08-27T23:31:00+02:00  27/08/2020   Oslo      Vest
# 5983  24008-2020-08-27T07:56:00+02:00  27/08/2020  Viken      Vest
#
#           Kommune                 Holdeplass_Fra  \
# 16     Ullensaker                        Furuset
# 52     Gamle Oslo       Kampen park  (mot Tøyen)
# ...

# %%
new_dataframe=dataframe[(dataframe['Kjøretøy_Kapasitet']<thresold_max) & (dataframe['Kjøretøy_lapasitet']>thresold_min)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\miniconda3\envs\dave3625\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Kjøretøy_lapasitet'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-3ce5664ea067> in <module>
# ...

# %%
new_dataframe=dataframe[(dataframe['Kjøretøy_Kapasitet']<thresold_max) & (dataframe['Kjøretøy_Kapasitet']>thresold_min)]

# %%
new_dataframe.shape new_dataframe
# Out:
#   File "<ipython-input-26-729358aa2097>", line 1
#     new_dataframe.shape new_dataframe
#                         ^
# SyntaxError: invalid syntax

# %%
new_dataframe.shape
new_dataframe
# Out:
#                                 TurId        Dato  Fylke    Område  \
# 0     15006-2020-08-10T10:24:00+02:00  10/08/2020  Viken      Vest
# 1     15002-2020-08-15T12:54:00+02:00  15/08/2020  Viken      Vest
# 2     15004-2020-08-03T09:54:00+02:00  03/08/2020  Viken      Vest
# 3     15003-2020-07-27T13:00:00+02:00  27/07/2020  Viken      Vest
# 4     15002-2020-08-27T07:15:00+02:00  27/08/2020  Viken      Vest
# ...                               ...         ...    ...       ...
# 5986  30020-2020-07-29T17:01:00+02:00  29/07/2020   Oslo   Nordøst
# 5987  30010-2020-07-29T14:44:00+02:00  29/07/2020   Oslo  Indre By
# 5992  14052-2020-08-17T07:40:00+02:00  17/08/2020   Oslo      Vest
# 5997   2007-2020-06-11T17:22:00+02:00  11/06/2020   Oslo  Indre By
# 5999  34013-2020-08-05T13:31:00+02:00  05/08/2020  Viken   Nordøst
#
#          Kommune                            Holdeplass_Fra  \
# 0          Bærum                               Nordliveien
# ...

# %%
thresold_max = dataframe['Passasjerer_Ombord'].quantile(0.90)
thresold_max
# Out:
# 13.0

# %%
dataframe[dataframe['Passasjerer_Ombord']>thresold_max]
# Out:
#                                 TurId        Dato  Fylke    Område  \
# 33    43008-2020-06-09T13:55:00+02:00  09/06/2020  Viken   Nordøst
# 75    40001-2020-06-13T16:51:00+02:00  13/06/2020  Viken   Nordøst
# 93    55002-2020-06-29T21:00:00+02:00  29/06/2020  Viken   Nordøst
# 116    3103-2020-06-01T07:14:00+02:00  01/06/2020   Oslo  Indre By
# 120   45007-2020-06-15T13:36:00+02:00  15/06/2020  Viken   Nordøst
# ...                               ...         ...    ...       ...
# 5909  55010-2020-06-17T13:35:00+02:00  17/06/2020  Viken       Sør
# 5929  25021-2020-08-05T06:58:00+02:00  05/08/2020  Viken      Vest
# 5932  43112-2020-06-18T07:29:00+02:00  18/06/2020  Viken   Nordøst
# 5944  40033-2020-08-24T06:21:00+02:00  24/08/2020  Viken   Nordøst
# 5970  30011-2020-06-14T22:14:00+02:00  14/06/2020  Viken   Nordøst
#
#           Kommune                                Holdeplass_Fra  \
# 33       Eidsvoll                                         Myrer
# ...

# %%
thresold_min = dataframe['Passasjerer_Ombord'].quantile(0.10)
thresold_min
# Out:
# -1.0

# %%
dataframe[data_frame['Passasjerer_Ombord']<thresold_min]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-afb45ef23bbb> in <module>
# ----> 1 dataframe[data_frame['Passasjerer_Ombord']<thresold_min]
#
# NameError: name 'data_frame' is not defined

# %%
new_dataframe=dataframe[(dataframe['Passasjerer_Ombord']<thresold_max) & (dataframe['Passasjerer_Ombord']>thresold_min)]

# %%
dataframe[data_frame['Passasjerer_Ombord']<thresold_min]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-afb45ef23bbb> in <module>
# ----> 1 dataframe[data_frame['Passasjerer_Ombord']<thresold_min]
#
# NameError: name 'data_frame' is not defined

# %%
new_dataframe.shape
# Out:
# (4695, 17)

# %%
dataframe[ dataframe.Holdeplass_Fra=="Københavngata"]
# Out:
# Empty DataFrame
# Columns: [TurId, Dato, Fylke, Område, Kommune, Holdeplass_Fra, Holdeplass_Til, Linjetype, Linjefylke, Linjenavn, Linjeretning, Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra, Tidspunkt_Faktisk_Avgang_Holdeplass_Fra, Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra, Tidspunkt_Planlagt_Avgang_Holdeplass_Fra, Kjøretøy_Kapasitet, Passasjerer_Ombord]
# Index: []

# %%
dataframe["Time"] = panda.to_datetime(dataframe['Time'])
dataframe.plot(x="Time", y=["counts"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\miniconda3\envs\dave3625\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Time'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-f5a311104362> in <module>
# ...

# %%
dataframe["Datp"] = panda.to_datetime(dataframe['Dato']) 
dataframe.plot(x="Dato", y=["counts"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-0e049e31afe3> in <module>
#       1 dataframe["Datp"] = panda.to_datetime(dataframe['Dato'])
# ----> 2 dataframe.plot(x="Dato", y=["counts"])
#       3 plt.show()
#
# ~\miniconda3\envs\dave3625\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     933
#     934                 # don't overwrite
# --> 935                 data = data[y].copy()
#     936
#     937                 if isinstance(data, ABCSeries):
#
# ~\miniconda3\envs\dave3625\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ...

# %%
dataframe["Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra"] = panda.to_datetime(dataframe['Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra']) 
dataframe.plot(x="Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra", y=["counts"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\miniconda3\envs\dave3625\lib\site-packages\dateutil\parser\_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     654         try:
# --> 655             ret = self._build_naive(res, default)
#     656         except ValueError as e:
#
# ~\miniconda3\envs\dave3625\lib\site-packages\dateutil\parser\_parser.py in _build_naive(self, res, default)
#    1240
# -> 1241         naive = default.replace(**repl)
#    1242
#
# ValueError: hour must be in 0..23
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ...
